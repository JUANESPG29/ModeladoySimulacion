# %% [markdown]
# <a href="https://colab.research.google.com/github/JUANESPG29/ModeladoySimulacion/blob/main/EJERCICIOS_CAPITULO2_JUAN_ESTEBAN_PABON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importamos las librerías

import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, Math

# Definición de funciones

# Función del método de euler
def euler_method(f, h, x0, ti, tf):
  N = int((tf-ti)/h)+1
  x = np.zeros(N)
  x[0] = x0
  for i in range(len(x)-1):
    x[i+1] = x[i] + h*f(x[i])

  t = np.linspace(ti,tf,N)
  
  return t,x

# Función para graficar el phase portrait y el vector field
def plot_phase_portrait(f,step,ti,tf,x0_i,x0_f,n):
  
  plt.figure(figsize=(20,9))

  plt.subplot(121)
  for i in np.linspace(x0_i,x0_f,n):
    x0 = i
    t,x = euler_method(f,step,x0,ti,tf)
    plt.plot(t,x,label=f'$x_0 = {i}$')
    plt.xlabel("$t$",fontsize=15)
    plt.ylabel("$x(t)$",fontsize=15)
    plt.title("Phase Portrait",fontsize=15)
    # plt.legend()
  plt.subplot(122)
  x_plot=np.linspace(x0_i,x0_f,100)
  plt.plot(x_plot,f(x_plot))
  plt.xlabel("$x$",fontsize=15)
  plt.ylabel("$\dot x$",fontsize=15)
  plt.title("Vector Field",fontsize=15)
  plt.show()

# %% [markdown]
# ## 2.1: A Geometric Way of Thinking
#
# In the next three exercises, interpret $\dot x = sin (x)$ as a flow on the line.

# %% [markdown]
# ### 2.1.1: Find all the fixed points of the flow.
#
# Para que un punto sea fijo, el flujo ($sin(x)$) tiene que ser 0.
#
# $\dot x = 0 ⇔ sin (x) = 0 ⇒ x∗=nπ$   $ ∀n ∈ N$
#
# Existen infinitos puntos fijos.

# %%
def func21(x):
  return np.sin(x)

h = 1e-3
ti = 0
tf = 30
x0_i = -2*np.pi
x0_f = 2*np.pi
n = 20

plot_phase_portrait(func21,h,ti,tf,x0_i,x0_f,10)

# %% [markdown]
# ## 2.2: Fixed Points and Stability

# %% [markdown]
# ### 2.2.1.
# $\dot x = 4x^2 - 16$
#
# Teóricamente se encontró que los puntos de equilibrio son:
#
# $x* = 2 \rightarrow$ Inestable
#
# $x* = -2 \rightarrow$ Estable

# %%
def func(t):
  return 4*t**2 - 16

h = 0.001
x0 = 1
ti = 0
tf = 0.1
x0_i = -3
x0_f = 3
n = 8

plot_phase_portrait(func,h,ti,tf,x0_i,x0_f,10)

# %% [markdown]
# ### 2.2.3
#
# $\dot x = x- x^{3}$
#
# Puntos de equilibrio:
#
# $x* = -1 \rightarrow$ Estable
#
# $x* = 0 \rightarrow$ Inestable
#
# $x* = 1 \rightarrow$ Estable

# %%
def func3(x):
  return x-x**3

h = 1e-3
ti = 0
tf = 2
x0_i = -2
x0_f = 2
n = 15
plot_phase_portrait(func3,h,ti,tf,x0_i,x0_f,20)

# %% [markdown]
# ## 2.4: Linear Stability Analysis

# %% [markdown]
# ### 2.4.1
#
# $\dot x = x(1-x)$
#
# Fixed points:
#
# $x* = 0 \rightarrow$ Inestable
#
# $x* = 1 \rightarrow$ Estable

# %%
def func8(x):
  return x*(1-x)

h = 1e-3
ti = 0
tf = 2
x0_i = -0.1
x0_f = 2
n = 20
plot_phase_portrait(func8,h,ti,tf,x0_i,x0_f,n)

# %% [markdown]
# ### 2.4.2
#
# $\dot x = x(1-x)(2-x)$
#
# Fixed points:
#
# $x* = 0 \rightarrow$ Inestable
#
# $x* = 1 \rightarrow$ Estable
#
# $x* = 2 \rightarrow$ Inestable

# %%
def func9(x):
  return x*(1-x)*(2-x)

h = 1e-3
ti = 0
tf = 3
x0_i = -0.001
x0_f = 2.001
n = 20
plot_phase_portrait(func9,h,ti,tf,x0_i,x0_f,n)

# %% [markdown]
# ### 2.4.3
#
# $\dot x = \tan x$
#
# Fixed points:
#
# $x* = 2 \pi n , n \in z \rightarrow$ Inestables

# %%
def func10(x):
  return np.tan(x)

h = 1e-3
ti = 0
tf = 0.5
x0_i = -1
x0_f = 1
n = 20
plot_phase_portrait(func10,h,ti,tf,x0_i,x0_f,n)

# %% [markdown]
# ## 2.7: Potentials

# %% [markdown]
# ### 2.7.1
#
# $\dot x = x(1-x)$
#
# Fixed points:
#
# $x* = 0 \rightarrow$ Inestable
#
# $x* = 1 \rightarrow$ Estable
#
# $V(x)=\frac{x^2}{2}-\frac{x^3}{3}+C$

# %%
fx=lambda x:x**2/2-x**3/3

x=np.linspace(-2,3,500)

aa=fx(x)


plt.xlabel("$x$",fontsize=10,color="red")
plt.ylabel("$V(x))$",fontsize=10,color="red")
plt.title("Función Vectorial",fontsize=20,color="red")

plt.plot(x,aa,color="green")
plt.grid()
plt.show()

# %%
def func71(x):
  return x*(1-x)

h = 1e-3
ti = 0
tf = 2
x0_i = -0.1
x0_f = 2
n = 20
plot_phase_portrait(func71,h,ti,tf,x0_i,x0_f,n)

# %% [markdown]
# ### 2.7.2
#
# $\dot x = 3$
#
# Fixed points: no tiene puntos fijos.
#
# $V(x)=-3x+C$

# %%
fx=lambda x:-3*x

x=np.linspace(-2,3,500)

aa=fx(x)


plt.xlabel("$x$",fontsize=10,color="red")
plt.ylabel("$V(x))$",fontsize=10,color="red")
plt.title("Función Vectorial",fontsize=20,color="red")

plt.plot(x,aa,color="green")
plt.grid()
plt.show()

# %%
def func72(x):
  return 0*x+3

h = 1e-3
ti = 0
tf = 2
x0_i = -0.1
x0_f = 2
n = 20
plot_phase_portrait(func72,h,ti,tf,x0_i,x0_f,n)

# %% [markdown]
# ## 2.8: Solving Equations on the Computer

# %% [markdown]
# ### 2.8.3
#
# (Calibrating the Euler method) The goal of this problem is to test the
# Euler method on the initial value problem $\dot x = -x,x(0) = 1.$
#
# a) Solve the problem analytically. What is the exact value of $x(1)$?
#
# b) Using the Euler method with step size $\Delta t = 1$, estimate $x(1)$ numerically—call the result $\hat x(1)$. Then repeat, using $\Delta t =   10^{–n}$
# , for $n$ =  1, 2, 3, 4.
#
# c) Plot the error $E = |\hat x(1) - x(1)|$ as a function of $\Delta t$. Then plot $\ln E$ vs. $\ln t$.
#
# Explain the results.

# %% [markdown]
# a) Este numeral se resolvió de forma analítica en el PDF. Se obtuvo que:
#
# $\boxed{x(1) = e^{-1} =  0.3678}$

# %% [markdown]
# b) Ahora, utilizando el método de Euler:

# %%
from IPython.display import display, Math

def func11(x):
  return -x

step = 1 # delta t
x0 = 1 # condición inicial x(0) = 1
ti = 0 # tiempo inicial
tf = 1 # tiempo final x(1)

for n in range(5):
  step = 10**(-n)
  t,x = euler_method(func11,step,x0,ti,tf)
  display(Math(f'\Delta t = {step} \\rightarrow \hat x = {x[-1]}')) # interesa conocer x(1), es decir el ultimo elemento del array
# Out:
# $$\Delta t = 1 \rightarrow \hat x = 0.0$$
# $$\Delta t = 0.1 \rightarrow \hat x = 0.3486784401$$
# $$\Delta t = 0.01 \rightarrow \hat x = 0.3660323412732296$$
# $$\Delta t = 0.001 \rightarrow \hat x = 0.36769542477096373$$
# $$\Delta t = 0.0001 \rightarrow \hat x = 0.36786104643292905$$

# %% [markdown]
# c)

# %%
def func11(x):
  return -x

step = 1 # delta t
x0 = 1 # condición inicial x(0) = 1
ti = 0 # tiempo inicial
tf = 1 # tiempo final x(1)

real_solution = np.exp(-1)
deltas = np.array([])
euler_errors = np.array([])

for n in range(5):
  step = 10**(-n)
  deltas = np.append(deltas,step)
  t,x = euler_method(func11,step,x0,ti,tf)
  euler_errors = np.append(euler_errors,abs(x[-1] - real_solution))

plt.figure(figsize=(16,9))
plt.subplot(121)
plt.plot(deltas,euler_errors)
plt.title("$E$ as a function of $\Delta t$",fontsize=15)
plt.xlabel("$\Delta t$",fontsize=15)
plt.ylabel("E",fontsize=15)

plt.subplot(122)
plt.plot(np.log(deltas),np.log(euler_errors))
plt.title("$\ln (E)$ as a function of $\ln (\Delta t)$",fontsize=15)
plt.xlabel("$\ln \Delta t$",fontsize=15)
plt.ylabel("$\ln (E)$",fontsize=15)


plt.show()

# %% [markdown]
# Como se puede ver, a medida que se aumenta el tamaño del paso, el error crece, pues la aproximación se hace cada vez más mala. Además, se puede ver que el error crece (o decrece) de forma lineal conforme se cambia el tamaño del paso. En pocas palabras, podemos concluir que el error y el tamaño del paso son directamente proporcionales.
#
# $E \propto \Delta t$

# %% [markdown]
# ### 2.8.6

# %%
### Runge-Kutta Method:

def runge_kutta(f,h,x0,ti,tf):
  N = int((tf-ti)/h)+1
  x = np.zeros(N)
  x[0] = x0
  for i in range(len(x)-1):
    k1 = f(x[i])*h
    k2 = f(x[i] + 0.5*k1)*h
    k3 = f(x[i] + 0.5*k2)*h
    k4 = f(x[i] + k3)*h

    x[i+1] = x[i] + (k1 + 2*k2 + 2*k3 + k4)/6
    
  t = np.linspace(ti,tf,N)
  
  return t,x

# %%
def func12(x):
  return x + np.exp(-x)
def func13(x):
  return 1 + x
def func14(x):
  return 0.9 + 0.4*x

h = 1
ti = 0
tf = 1
x0 = 0

plt.figure(figsize=(20,9))

for i in range(3):
  h = 10**(-i)

  plt.subplot(1,3,i+1)
  t,x = euler_method(func12,h,x0,ti,tf)
  plt.plot(t,x,label = 'Euler Method')
  t_r,x_r = runge_kutta(func12,h,x0,ti,tf)
  plt.plot(t_r,x_r,label = 'Runge - Kutta')
  plt.title(f"Approximation using $\Delta t = {h}$\n Euler Method $ \\rightarrow x(1) = {format(x[-1],'.4g')}$ \n Runge - Kutta $\\rightarrow x(1) = {format(x_r[-1],'.4g')}$")

  plt.xlabel("$t$",fontsize=15)
  plt.ylabel("$x(t)$",fontsize=15)
  # t2,x2 = euler_method(func13,h,x0,ti,tf)
  # plt.plot(t2,x2,label = 'Upper limit')

  # t3,x3 = euler_method(func14,h,x0,ti,tf)
  # plt.plot(t3,x3,label = 'Lower Limit')


  # Analytical solutions of the bounds:
  # t_a = np.linspace(0,1,1000)
  # x2_a =  np.exp(t_a) - 1
  # plt.plot(t_a,x2_a)
  # x3_a = (9/4) * (np.exp(0.4*t_a) - 1)
  # plt.plot(t_a,x3_a)
  plt.legend()
  plt.show()
