# %% [markdown]
# <a href="https://colab.research.google.com/github/JUANESPG29/ModeladoySimulacion/blob/main/EjerciciosenclaseCap3_Strogatz_Juan_Esteban_Pab%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 3.1.1
#
# ### Sistema 1:
#
# 1. \begin{equation}
# \dot { x } =1+rx+x^2
# \end{equation}

# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

# %%
x=np.linspace(-10,10,100)
r=-5
x_dot=1+r*x+x**2
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.spines['left'].set_position(('data',0.0))
ax.spines['bottom'].set_position(('data',0.0))
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')

#plt.axis([-5, 5, -5, 5])
plt.plot(x,x_dot)
plt.grid()

x=sp.symbols('x')
x_dot1=1+r*x+x**2
roots=sp.solve(x_dot1)
print(roots)
for j in range(len(roots)):
  plt.plot(roots[j],0,'ro')
# Out:
# [5/2 - sqrt(21)/2, sqrt(21)/2 + 5/2]

# %%
def fun (t,x,r,b):
  return 1+r*x+x**b
  ##return r*x-x**3
  

r,b=-5,2

ti=0; tf=1; dt=100
tspam=[ti, tf]
t=np.linspace(ti,tf,dt)
for x0 in np.arange(-5,7,0.5):
  sol=solve_ivp(fun,tspam,[x0],args=(r,b),t_eval=t)
  plt.plot(sol.t, sol.y[0])

plt.axis([ti, tf, -10, 10])
plt.grid()

# %%
ti=0; tf=100; dt=100
tspam=[ti, tf]

for r in np.arange(-5,5,0.2):
  for x0 in np.arange(-5,5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,b))
    plt.scatter(r, sol.y[0][-1], color='darkgreen', marker='.')

tspam=[ti, -tf]

for r in np.arange(-5,5,0.2):
  for x0 in np.arange(-5,5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,b))
    plt.scatter(r, sol.y[0][-1], color='red', marker='.')


plt.axis([-5, 5, -10, 10])
plt.grid()

# %% [markdown]
# # 3.1.2
#
#
# \begin{equation}
# \dot { x } =r+x-ln(1+x)
# \end{equation}

# %%
x=np.linspace(-10,10,100)
r=-1
x_dot=r+x-np.log(1+x)
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.spines['left'].set_position(('data',0.0))
ax.spines['bottom'].set_position(('data',0.0))
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')

#plt.axis([-5, 5, -5, 5])

plt.xlabel("$x$",fontsize=15)
plt.ylabel("$\dot{x}$",fontsize=15)
plt.title("Función",fontsize=20,color="red")

plt.plot(x,x_dot)
plt.grid()

x=sp.symbols('x')
x_dot2=r+x-sp.log(1+x)
roots=sp.solve(x_dot2)
print(roots)
for j in range(len(roots)):
  plt.plot(roots[j],0,'ro')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in log
#   after removing the cwd from sys.path.
# [-1 - LambertW(-exp(-2)), -1 - LambertW(-exp(-2), -1)]

# %%
def fun2 (t,x,r,b):
  return r+x-np.log(1+x)
  

r,b=-1,0

ti=0; tf=1; dt=10
tspam=[ti, tf]
t=np.linspace(ti,tf,dt)
for x0 in np.arange(-2,4,0.5):
  sol=solve_ivp(fun2,tspam,[x0],args=(r,b),t_eval=t)
  plt.plot(sol.t, sol.y[0])

plt.axis([ti, tf, -10, 10])
plt.grid()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-55-38690bdbc6f8> in <module>()
#       9 t=np.linspace(ti,tf,dt)
#      10 for x0 in np.arange(-2,4,0.5):
# ---> 11   sol=solve_ivp(fun2,tspam,[x0],args=(r,b),t_eval=t)
#      12   plt.plot(sol.t, sol.y[0])
#      13
#
# /usr/local/lib/python3.7/dist-packages/scipy/integrate/_ivp/ivp.py in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     575     status = None
#     576     while status is None:
# --> 577         message = solver.step()
#     578
#     579         if solver.status == 'finished':
#
# /usr/local/lib/python3.7/dist-packages/scipy/integrate/_ivp/base.py in step(self)
#     180         else:
#     181             t = self.t
# --> 182             success, message = self._step_impl()
#     183
#     184             if not success:
#
# /usr/local/lib/python3.7/dist-packages/scipy/integrate/_ivp/rk.py in _step_impl(self)
#     144
#     145             y_new, f_new = rk_step(self.fun, t, y, self.f, h, self.A,
# --> 146                                    self.B, self.C, self.K)
#     147             scale = atol + np.maximum(np.abs(y), np.abs(y_new)) * rtol
#     148             error_norm = self._estimate_error_norm(self.K, h, scale)
#
# /usr/local/lib/python3.7/dist-packages/scipy/integrate/_ivp/rk.py in rk_step(fun, t, y, f, h, A, B, C, K)
#      65         K[s] = fun(t + c * h, y + dy)
#      66
# ---> 67     y_new = y + h * np.dot(K[:-1].T, B)
#      68     f_new = fun(t + h, y_new)
#      69
#
# KeyboardInterrupt:

# %%
ti=0; tf=100; dt=100
tspam=[ti, tf]

for r in np.arange(-5,5,0.2):
  for x0 in np.arange(-5,5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,b))
    plt.scatter(r, sol.y[0][-1], color='darkgreen', marker='.')

tspam=[ti, -tf]

for r in np.arange(-5,5,0.2):
  for x0 in np.arange(-5,5,0.7):
    sol=solve_ivp(fun,tspam,[x0],args=(r,b))
    plt.scatter(r, sol.y[0][-1], color='red', marker='.')


plt.axis([-5, 5, -10, 10])
plt.grid()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-2263be9c4f9c> in <module>()
#      11 for r in np.arange(-5,5,0.2):
#      12   for x0 in np.arange(-5,5,0.7):
# ---> 13     sol=solve_ivp(fun,tspam,[x0],args=(r,b))
#      14     plt.scatter(r, sol.y[0][-1], color='red', marker='.')
#      15
#
# /usr/local/lib/python3.7/dist-packages/scipy/integrate/_ivp/ivp.py in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     575     status = None
#     576     while status is None:
# --> 577         message = solver.step()
#     578
#     579         if solver.status == 'finished':
#
# /usr/local/lib/python3.7/dist-packages/scipy/integrate/_ivp/base.py in step(self)
#     180         else:
#     181             t = self.t
# --> 182             success, message = self._step_impl()
#     183
#     184             if not success:
#
# /usr/local/lib/python3.7/dist-packages/scipy/integrate/_ivp/rk.py in _step_impl(self)
#     144
#     145             y_new, f_new = rk_step(self.fun, t, y, self.f, h, self.A,
# --> 146                                    self.B, self.C, self.K)
#     147             scale = atol + np.maximum(np.abs(y), np.abs(y_new)) * rtol
#     148             error_norm = self._estimate_error_norm(self.K, h, scale)
#
# /usr/local/lib/python3.7/dist-packages/scipy/integrate/_ivp/rk.py in rk_step(fun, t, y, f, h, A, B, C, K)
#      63     for s, (a, c) in enumerate(zip(A[1:], C[1:]), start=1):
#      64         dy = np.dot(K[:s].T, a[:s]) * h
# ---> 65         K[s] = fun(t + c * h, y + dy)
#      66
#      67     y_new = y + h * np.dot(K[:-1].T, B)
#
# /usr/local/lib/python3.7/dist-packages/scipy/integrate/_ivp/base.py in fun(t, y)
#     137         def fun(t, y):
#     138             self.nfev += 1
# --> 139             return self.fun_single(t, y)
#     140
#     141         self.fun = fun
#
# /usr/local/lib/python3.7/dist-packages/scipy/integrate/_ivp/base.py in fun_wrapped(t, y)
#      19
#      20     def fun_wrapped(t, y):
# ---> 21         return np.asarray(fun(t, y), dtype=dtype)
#      22
#      23     return fun_wrapped, y0
#
# /usr/local/lib/python3.7/dist-packages/scipy/integrate/_ivp/ivp.py in <lambda>(t, x, fun)
#     513         # additional parameters.  Pass in the original fun as a keyword
#     514         # argument to keep it in the scope of the lambda.
# --> 515         fun = lambda t, x, fun=fun: fun(t, x, *args)
#     516         jac = options.get('jac')
#     517         if callable(jac):
#
# <ipython-input-31-e55da13f8681> in fun(t, x, r, b)
#       1 def fun (t,x,r,b):
# ----> 2   return 1+r*x+x**b
#       3   ##return r*x-x**3
#       4
#       5
#
# KeyboardInterrupt:
